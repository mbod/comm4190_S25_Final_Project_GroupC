# %% [markdown]
# # Benchmarking #
# Let's see what happens if I try to do "Scenario 1: The full experience" with ChatGPT. I am going to provide ChatGPT with the prompt from the Overview notebook and see what happens!

# %% [markdown]
# > Hi there! I'm **HealthPlan Helper**, here to make the U.S. healthcare system a little easier to navigate. Whether you're choosing a new health plan, trying to understand confusing terms, or just figuring out what coverage fits your needs best—I’ve got your back.
# >
# > To get started, could you tell me a bit about what you need help with today? Do you want help picking a health plan, estimating your costs, or understanding how something like a deductible or coinsurance works?
# >
# > Take your time—there’s no rush!

# %% [markdown]
# Can you help me pick a healthcare plan?

# %% [markdown]
# > Absolutely—I’d be glad to help you pick a healthcare plan!
# >
# > To get started, I’ll walk you through a few quick questions so we can figure out what kind of coverage might be the best fit for you. You can skip anything you're not sure about:
# >
# > 1. **Age** – How old are you?
# > 2. **Health conditions** – Do you have any ongoing health issues or prescriptions (e.g., asthma, anxiety, diabetes)?
# > 3. **Past or expected healthcare usage** – Do you usually see doctors a lot during the year, or just for > checkups? Any surgeries or specialists expected?
# > 4. **Do you already have some plan options to compare?** (Like brochures, PDFs, or summaries of benefits from an employer or marketplace?)
# >
# > Once we have that info, I can help estimate your costs, compare plans, and break it all down simply. Let’s take it one step at a time—ready when you are!

# %% [markdown]
# 1. 105 years old 2. Diabetes 3. I see a specialist about 10x a year. 4. See attached. (I attached an IBX brochure)

# %% [markdown]
# > Thanks for sharing everything, and wow—105! That’s amazing 🎉 I really admire you for being on top of your healthcare planning.
# >
# > Based on your info:
# > - You **have diabetes** (so prescription coverage and chronic condition management are key),
# > - You **see a specialist about 10 times a year**,
# > - And you've uploaded a brochure for **Independence Blue Cross (IBX) Gold plans**.
# >
# > Let’s walk through and compare **two solid Gold options** from that brochure, ideal for someone with frequent healthcare needs:
# >
# > ---
# >
# > ### 💡 Plan Comparison:
# > We’ll look at **Keystone HMO Gold Proactive** vs. **Personal Choice PPO Gold**
# >
# > #### ✅ 1. **Keystone HMO Gold Proactive**
# > - **Deductible**: $0
# > - **Specialist copay (Tier 1)**: $40 (or $30 for virtual)
# > - **Primary care (Tier 1)**: $15 (or $10 virtual)
# > - **Prescription (low-cost generic)**: $3
# > - **Specialist visits (10x/year)**: ~$400 total (if Tier 1)
# > - **Out-of-pocket max**: $9,200
# >
# > ✅ Bonus: Use Tier 1 providers to keep costs low.
# > 🔁 **Referrals required**, but you get coordinated care.
# >
# > ---
# >
# > #### ✅ 2. **Personal Choice PPO Gold**
# > - **Deductible**: $0
# > - **Specialist copay**: $65 (or $45 virtual)
# > - **Primary care**: $30 (or $20 virtual)
# > - **Prescription (low-cost generic)**: $3
# > - **Specialist visits (10x/year)**: ~$650 total
# > - **Out-of-pocket max**: $8,250
# >
# > ✅ Bonus: **No referrals needed** and includes **out-of-network coverage**
# > 🌍 Ideal if you travel or want flexibility in choosing providers.
# >
# > ---
# >
# > ### 🧾 Estimated Annual Costs (Excluding Premiums)
# > | Category            | Keystone HMO Gold Proactive | Personal Choice PPO Gold |
# > |---------------------|-----------------------------|---------------------------|
# > | 10 Specialist visits| $400 (Tier 1)               | $650                      |
# > | PCP (2 visits)      | $30 (Tier 1)                | $60                       |
# > | Prescriptions       | ~$100 est. (varies)         | ~$100                     |
# > | **Est. Total**      | **~$530**                   | **~$810**
# >
# > This is **just an estimate**, and actual costs may vary based on specific medications or Tier 2/3 usage.
# >
# > ---
# >
# > ### 💬 Recommendation
# > If:
# > - You **stay in-network** and don’t mind **referrals**,
# > 👉 **Keystone HMO Gold Proactive** will save you money.
# >
# > If:
# > - You **value flexibility** and may go **out-of-network**,
# > 👉 **Personal Choice PPO Gold** is better despite higher costs.
# >
# > ---
# >
# > Would you like me to help estimate your **monthly premium** or visualize the yearly cost comparison next? Or are there other plans > you'd like to compare too?

# %% [markdown]
# What about the silver plans?

# %% [markdown]
# > Great question! Let’s take a look at **Silver plans** from the same Independence Blue Cross (IBX) brochure, especially since they can offer **lower premiums**, though sometimes with higher out-of-pocket costs.
# >
# > We’ll focus on two Silver plans that might work for you:
# > 1. **Keystone HMO Silver Proactive Select**
# > 2. **Personal Choice PPO Silver Classic**
# >
# > Since you **see a specialist ~10 times/year**, have **diabetes**, and are 105 years old, keeping routine costs predictable is > important. Let’s break these down:
# >
# > ---
# >
# > ## 🥈 1. **Keystone HMO Silver Proactive Select**
# > ➡️ *Lower out-of-pocket costs if you use Tier 1 providers*
# >
# > - **Deductible**:
# >   - **Tier 1**: $0
# >   - **Tier 2/3**: $6,000
# > - **Specialist copay (Tier 1)**: $90 (or $60 virtual)
# > - **Primary care (Tier 1)**: $40 (or $30 virtual)
# > - **Low-cost generic drugs**: $5, no deductible
# > - **Out-of-pocket max**: $9,200
# > - **Referrals required**
# > - **Virtual mental health visits**: $0
# >
# > 💡 **Estimated cost for 10 Tier 1 specialist visits**: $900
# > 💡 2 PCP visits: $80
# > 💊 Prescriptions: ~$100/year
# >
# > **Total estimate (excluding premium)**: ~$1,080
# >
# > ---
# >
# > ## 🥈 2. **Personal Choice PPO Silver Classic**
# > ➡️ *More flexibility—no referrals, includes out-of-network coverage*
# >
# > - **Deductible**: $3,500
# > - **Specialist copay**: $75 (or $50 virtual)
# > - **Primary care**: $30 (or $20 virtual)
# > - **Low-cost generic drugs**: $3
# > - **Out-of-pocket max**: $8,250
# > - **No referrals required**
# >
# > 💡 10 specialist visits: ~$750
# > 💡 2 PCP visits: ~$60
# > 💊 Prescriptions: ~$100
# >
# > **Total estimate (excluding premium)**: ~$910
# *(but you hit the deductible faster if you need imaging, labs, or hospital visits)*
# >
# > ---
# >
# > ## 🧾 Side-by-Side Summary
# >
# > | Plan                                 | Est. Yearly Out-of-Pocket | Flexibility       | Deductible (Tier 1) | Referrals |
# > |--------------------------------------|----------------------------|-------------------|----------------------|-----------|
# > | **Keystone Silver Proactive Select** | ~$1,080                    | Lower, Tier-based | $0 (Tier 1 only)     | Yes       |
# > | **PPO Silver Classic**               | ~$910                      | High              | $3,500               | No        |
# >
# > ---
# >
# > ### 💬 My Thoughts:
# > - If you're **okay staying in-network** and navigating **tiered pricing**, **Keystone HMO Silver Proactive Select** is solid—but watch those Tier 2/3 costs.
# > - If you **prefer no referrals**, want to choose your own specialists more freely, or travel outside your local area, **PPO Silver Classic** might be worth > the higher deductible.
# >
# > Would you like me to compare any of these to the Gold plans we looked at? Or would a **visual cost comparison chart** help?

# %% [markdown]
# Let's do a visual cost comparison chart

# %% [markdown]
# > Here’s a visual comparison of your estimated **annual out-of-pocket costs** (not including premiums):
# >
# > - **Keystone Gold Proactive** is the most cost-effective if you stay within Tier 1 providers.
# > - **PPO Gold** costs a bit more, but gives you more freedom and no referrals.
# > - **Keystone Silver Proactive Select** has higher costs unless you strictly stick to Tier 1.
# > - **PPO Silver Classic** falls in between—more flexible, but that deductible can add up.
# >
# > Would you like to estimate total cost **including premiums** next, or compare a few specific services like prescriptions or imaging?
# >
# > ![](attachment:55b17332-3e0b-41bb-bb59-17f424be64f9.png)

# %% [markdown]
# Could I see Dr. Vicki Bralow, DO with any of these plans?

# %% [markdown]
# > The IBX brochure doesn’t list individual doctors like Dr. Vicki Bralow, DO, by name—but it does point you to where you can check if she’s **in-network** for any of the plans (like Keystone HMO or Personal Choice PPO).
# >
# > ### Here’s what to do:
# > You can search the IBX provider network using their official tool:
# >
# > 🔗 **[Find a Doctor - IBX Provider Finder](https://www.ibx.com/providerfinder)**
# >
# > Once you're there:
# > 1. **Enter her name**: “Vicki Bralow, DO”
# > 2. **Choose the plan** you’re considering (e.g., “Keystone HMO Proactive” or “Personal Choice PPO”).
# > 3. Click **Search** to see if she’s in-network and what tier (for HMO plans) she falls under.
# >
# > ---
# >
# > If you’d like, I can walk you through that provider search step-by-step. Or if you’d rather, I can check it for you—just let me know what city or ZIP code her office is in.
# >
# > Would you like help doing that now?

# %% [markdown]
# Can you check it for me? City: Philadelphia. Zip code: 19147

# %% [markdown]
# > Unfortunately, I can’t check the provider network directly for you. But you can easily find out if Dr. Vicki Bralow, DO, is in-network by visiting the official tool here:
# >
# > 🔗 [**IBX Find a Doctor**](https://www.ibx.com/providerfinder)
# >
# > Here's how to check:
# > 1. Go to the link above.
# > 2. Under “**Search by Name**,” enter: **Dr. Vicki Bralow**
# > 3. Use the ZIP code **19147**.
# > 4. Then select your plan from the dropdown (like **Keystone HMO Proactive** or **Personal Choice PPO**).
# > 5. Click **Search** to view her status and tier.
# >
# > This will show whether she’s in-network—and if she’s Tier 1, 2, or 3 for Keystone HMO plans.
# >
# > If you run into any trouble, I can walk through it with you step-by-step. Want help with that?

# %% [markdown]
# Can you tell me more about Philadelphia, PA? What are some famous foods from there?

# %% [markdown]
# > Absolutely! Philadelphia, PA is an iconic city with deep historical roots and **legendary food**. It’s the birthplace of American independence and home to so many uniquely Philly traditions, tastes, and vibes. Here's a quick tour:
# >
# > ---
# >
# > ## 🏛️ Quick Philly Highlights:
# >  **Independence Hall**: Where the Declaration of Independence and Constitution were signed.
# ->  **Liberty Bell**: Famous for its crack and symbolism of freedom.
# ->  **Rocky Steps**: The steps of the Philadelphia Museum of Art—run up them and feel the glory!
# > - **Mummers Parade**: A flashy, quirky New Year’s Day tradition.
# > - **Love Park**: Home to the iconic “LOVE” sculpture.
# >
# > ---
# >
# > ## 🍽️ Famous Philadelphia Foods:
# >
# > ### 🧀 **1. Philly Cheesesteak**
# > - Thinly sliced beef on a hoagie roll, smothered in melted cheese (Cheez Whiz, provolone, or American).
# > - Classic toppings: fried onions, mushrooms, peppers.
# > - Famous spots: **Pat’s King of Steaks**, **Geno’s**, **Jim’s South St.**, or local favorite **Dalessandro’s**.
# >
# > ---
# >
# > ### 🥯 **2. Soft Pretzels**
# > - Twisty, doughy, slightly salty—best from a street cart or Wawa.
# > - Often eaten with mustard (never ketchup 😄).
# >
# > ---
# >
# > ### 🧁 **3. Tastykakes**
# > - Philly’s beloved packaged snack cakes: Butterscotch Krimpets, Peanut Butter Kandy Kakes, and more.
# > - You’ll find them in nearly every convenience store in town.
# >
# > ---
# >
# > ### 🌭 **4. Italian Hoagies**
# > - Classic cold sub with meats, provolone, lettuce, tomato, onions, oil, and vinegar.
# v- Get one at **Primo Hoagies**, **Sarcone’s Deli**, or a corner Italian market.
# >
# > ---
# >
# > ### 🍕 **5. Tomato Pie**
# > - Thick, focaccia-like crust topped with sweet tomato sauce. Often served cold.
# > - It’s a bakery staple—not your average pizza!
# >
# > ---
# >
# > ### 🧁 **6. Water Ice (a.k.a. Italian Ice)**
# > - Smooth, sweet, and icy—comes in every fruity flavor you can imagine.
# > - Try **John’s**, **Pop’s**, or **Rita’s** in the summer.
# >
# > ---
# >
# > ### 🐷 **7. Roast Pork Sandwich**
# > - Tender pork, sharp provolone, and sautéed broccoli rabe on a crusty roll.
# > - Locals argue it’s **better than the cheesesteak**. (Try **DiNic’s** at Reading Terminal Market.)
# >
# > ---
# >
# > Would you like restaurant recommendations in the 19147 area? Or want to explore more of Philly’s hidden food gems?

# %% [markdown]
# ## Analysis ##

# %% [markdown]
# ChatGPT was able to do a really good job! Reviewing the output, I see a few things that could be improved.
#
# - Ability to access the Internet
# - Awareness of capabilies: it was frustrating when ChatGPT told me it could search whether a provider was in-network for me, but then it wasn't able to.
# - Staying on task
# - No use of emojis- this is a serious topic!
# - Providing **brief** outputs that are not going to overwhelm the user
